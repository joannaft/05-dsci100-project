# %% [markdown]
# ### Background information:
# - Research conducted by UBC research group, Pacific Laboratory for Artificial Intelligence
# - [how data was collected here]

# %% [markdown]
# ### Background Information:
# This group project seeks to answer the question "Can the status of subscribing to a game-related newsletter be predicted from age and hours played?" This is part of a larger study that is looking for player characteristics and behaviours that are the most predictive of subscribing to a game-related newsletter, and how these features differ between various player types.
#
# This data was collected through a minecraft server run by The Pacific Laboratory for Arfificial Intelligence (PLAI), a research group based in the Department of Computer Science at the University of British Columbia, with the goal of creating an AI that is able to understand speech, respond and act in a virtual environment.
#
# ### Data
# The data is tracked across 2 datasets:
#
# ```players.csv``` – 196 observations, 7 variables. This gives information on the demographics of players who log onto PLAI's minecraft server, recording variables like name, age and minecraft experience.
#
# | Variable | Description | Data type |
# |----------|-------------|-----------|
# | experience | Self-identifying Level of Experience | chr|
# | subscribe  | Game Newsletter Subscription Status | lgl |
# | hashedEmail | Hashed Version of Player Email | chr |
# | played_hours | Hours spent in game | dbl |
# | name | Name of player | chr |
# | gender | Gender of player | chr |
# | age | Age of player | dbl |
#
# ```sessions.csv``` – 1535 observations, 5 observations. This gives information on each individual playing session logged on PLAICRAFT, recording the email of the player who logged in, and how long the session lasted.
# | Variable | Description | Data type |
# |----------|-------------|-----------|
# | hashedEmail | Hashed Version of Player Email | chr |
# | start_time | Start Time of Session | chr|
# | end_time | End Time of Session | chr |
# | original_start_time | Start Time Represented in UNIX time | dbl |
# | original_end_time | End Time Represented in UNIX time | dbl |
